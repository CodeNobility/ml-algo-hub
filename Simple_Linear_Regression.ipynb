# %%
import pandas as pd

# %%
dataset=pd.read_csv(r"/Users/princegupta/Documents/data science/dataset/placement_linear.csv")

# %%
dataset.head(6)
# Out:
#    cgpa  package
# 0  5.84    19.85
# 1  6.39    19.45
# 2  5.89    21.30
# 3  5.44    16.83
# 4  5.60    16.95
# 5  7.30    28.60

# %%
dataset.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
dataset.shape
# Out:
# (300, 2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x="cgpa",y="package",data=dataset)
plt.show()

# %%
x=dataset[["cgpa"]]
y=dataset["package"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=17)

# %%
x_train.shape,y_train.shape
# Out:
# ((240, 1), (240,))

# %%
x_test.shape,y_test.shape
# Out:
# ((60, 1), (60,))

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict([[7.30]])
# Out:
# /Users/princegupta/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([26.53970581])

# %%
lr.score(x_test,y_test)*100
# Out:
# 94.5801791397992

# %%
lr.coef_
# Out:
# array([5.07613536])

# %%
lr.intercept_
# Out:
# -10.516082315941741

# %%
5.07613536*5.89-10.516082315941741
# Out:
# 19.382354954458258

# %%
y_pred=lr.predict(x)

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x="cgpa",y="package",data=dataset)
plt.plot(dataset["cgpa"],y_pred,c="r")
plt.legend(["original_data", "predict_line"])
plt.show()

# %%
sns.boxplot(dataset["package"])
plt.show()
