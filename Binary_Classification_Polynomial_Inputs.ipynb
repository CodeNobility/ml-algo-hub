# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"/Users/princegupta/Documents/data science/dataset/synthetic_placement_data.csv")

# %%
dataset.head(3)
# Out:
#    cgpa  score  placed
# 0  6.50   7.79       0
# 1  8.80   7.14       1
# 2  7.93   6.24       1

# %%
plt.figure(figsize=(8,4))
sns.scatterplot(x="cgpa",y="score",hue="placed",data=dataset)
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["placed"]

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.columns
# Out:
# Index(['cgpa', 'score'], dtype='object')

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf=PolynomialFeatures(degree=3)
pf.fit(x)
x=pf.transform(x)

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x=pd.DataFrame(x)

# %%
x.columns
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=30)

# %%
x_train.shape
# Out:
# (400, 10)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.69

# %%
test=pf.transform([[8.8,7.1]])
# Out:
# /Users/princegupta/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
lr.predict(test)
# Out:
# array([1])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
x_test
# Out:
#        0     1     2        3        4        5           6           7  \
# 21   1.0  5.56  6.52  30.9136  36.2512  42.5104  171.879616  201.556672
# 239  1.0  5.71  6.51  32.6041  37.1721  42.3801  186.169411  212.252691
# 103  1.0  7.03  5.35  49.4209  37.6105  28.6225  347.428927  264.401815
# 273  1.0  8.65  6.59  74.8225  57.0035  43.4281  647.214625  493.080275
# 22   1.0  6.17  8.88  38.0689  54.7896  78.8544  234.885113  338.051832
# ..   ...   ...   ...      ...      ...      ...         ...         ...
# 242  1.0  8.66  7.99  74.9956  69.1934  63.8401  649.461896  599.214844
# 141  1.0  6.01  6.29  36.1201  37.8029  39.5641  217.081801  227.195429
# 3    1.0  7.39  8.26  54.6121  61.0414  68.2276  403.583419  451.095946
# 468  1.0  5.89  7.27  34.6921  42.8203  52.8529  204.336469  252.211567
# 41   1.0  6.98  7.42  48.7204  51.7916  55.0564  340.068392  361.505368
#
#               8           9
# 21   236.357824  277.167808
# 239  241.990371  275.894451
# 103  201.216175  153.130375
# 273  375.653065  286.191179
# 22   486.531648  700.227072
# ..          ...         ...
# 242  552.855266  510.082399
# 141  237.780241  248.858189
# 3    504.201964  563.559976
# 468  311.303581  384.240583
# 41   384.293672  408.518488
#
# [100 rows x 10 columns]

# %%
y_test
# Out:
# 21     0
# 239    0
# 103    1
# 273    0
# 22     1
#       ..
# 242    1
# 141    0
# 3      1
# 468    1
# 41     1
# Name: placed, Length: 100, dtype: int64

# %%
test2=pf.transform([[6.5,7.7]])
# Out:
# /Users/princegupta/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
lr.predict(test2)
# Out:
# array([1])

# %%
test3=pf.transform([[5.7,6.5]])
# Out:
# /Users/princegupta/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
lr.predict(test3)
# Out:
# array([1])
