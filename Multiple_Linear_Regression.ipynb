# %%
import pandas as pd

# %%
dataset=pd.read_csv(r"/Users/princegupta/Documents/data science/dataset/salary_data_2.csv")

# %%
dataset.head(3)
# Out:
#    Age  Experience  Salary
# 0   50          32  342752
# 1   36          14  250376
# 2   29          11  193669

# %%
dataset.shape
# Out:
# (1000, 3)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()

# %% [markdown]
# # splliting the data into train and test part

# %%
x = dataset.iloc[:,:-1]
y = dataset["Salary"]

# %%
x.ndim, y.ndim
# Out:
# (2, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=42)

# %%
x_train.shape, y_train.shape
# Out:
# ((700, 2), (700,))

# %%
x_test.shape, y_test.shape
# Out:
# ((300, 2), (300,))

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)*100
# Out:
# 97.84176202968582

# %%
#equation :  y=m1x + m2x + c

# %%
lr.coef_   # m1 and m2
# Out:
# array([5599.09741338, 1410.82516883])

# %%
lr.intercept_   # slope "c"
# Out:
# 17297.287596438342

# %%
lr.predict([[36,14]])
# Out:
# /Users/princegupta/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([238616.3468417])

# %%
lr.predict([[29,11]])
# Out:
# /Users/princegupta/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([195190.18944155])

# %%
lr.predict([[50,32]])
# Out:
# /Users/princegupta/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([342398.56366798])

# %%
# putting the input value age and experience into equation manually

# %%
5599.09741338*50+1410.82516883*32+17297.287596438342
# Out:
# 342398.5636679984

# %%
lr.predict(x_test)
# Out:
# array([160140.5765305 , 244259.64751703, 331156.16557927, 307348.95075693,
#        217586.57909506, 214809.13201935, 165739.67394388, 385824.72106813,
#        234428.07459715, 335388.64108577, 392834.64365034, 140477.43069074,
#        218997.4042639 , 324146.24299706, 164328.84877504, 168517.12101959,
#        305938.1255881 , 238616.3468417 , 317136.32041485, 297517.37783705,
#        140477.43069074, 216219.95718819, 234428.07459715, 141888.25585958,
#        251269.57009924, 314358.87333914, 378814.79848592, 188180.26685934,
#        405487.86690788, 289096.63008601, 266656.03717054, 144709.90619724,
#        286319.1830103 , 328378.71850356, 338166.08816148, 182536.96618401,
#        308715.57266381, 168517.12101959, 367616.60365916, 242848.8223482 ,
#        293329.10559251, 381636.44882358, 385824.72106813, 255457.84234379,
#        325557.06816589, 175527.0436018 , 209210.03460598, 367616.60365916,
# ...

# %%
dataset.columns
# Out:
# Index(['Age', 'Experience', 'Salary'], dtype='object')

# %%
y_pred=lr.predict(x)

# %%
plt.figure(figsize=(14,5))
plt.subplot(1,2,1)
sns.scatterplot(x="Age", y="Salary", data=dataset)
plt.plot(dataset["Age"],y_pred,c="r")
plt.legend(["original_data", "predict_line"])

plt.subplot(1,2,2)
sns.scatterplot(x="Experience", y="Salary", data=dataset)
plt.plot(dataset["Experience"], y_pred, c="brown")
plt.legend(["original_data", "predict_line"])
plt.show()
