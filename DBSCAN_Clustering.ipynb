# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv(r"/Users/princegupta/Documents/data science/dataset/placement_data.csv")

# %%
dataset.head(3)
# Out:
#        cgpa     score  placed
# 0  7.076327  6.373941       0
# 1  6.916728  6.255223       0
# 2  5.102568  4.921385       0

# %%
sns.scatterplot(x="cgpa",y="score",data=dataset)
plt.show()

# %%
dataset.drop(columns=["placed"],inplace=True)

# %%
dataset.head(2)
# Out:
#        cgpa     score
# 0  7.076327  6.373941
# 1  6.916728  6.255223

# %%
from sklearn.cluster import DBSCAN

# %%
db=DBSCAN(eps=0.3,min_samples=4)

# %%
dataset["predict"]=db.fit_predict(dataset)

# %%
dataset
# Out:
#          cgpa     score  predict
# 0    7.076327  6.373941        0
# 1    6.916728  6.255223        0
# 2    5.102568  4.921385        0
# 3    6.364991  6.658884        0
# 4    6.520782  7.251650        0
# ..        ...       ...      ...
# 495  7.627821  7.620380        0
# 496  8.826458  8.564143        0
# 497  5.275832  5.399985        0
# 498  5.228219  5.888297        0
# 499  6.128748  5.435044        0
#
# [500 rows x 3 columns]

# %%
sns.scatterplot(x="cgpa",y="score",data=dataset,hue="predict")
plt.show()

# %% [markdown]
# # conclusion : DBSCAN is not suitable for the dataset which is linearly seperable with the straight line
